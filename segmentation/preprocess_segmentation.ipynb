# %% [markdown]
# ### resample subimage(s): take it randomly

# %%
from PIL import Image
import numpy as np
import os

def crop_resample(image_file, mask_file, outdir, outfile,
                  num_resample=1):
    """Crops a patch from a given image, and resample random patches (optional).

    Given a 2D image and binary mask image, crops the bounding box
    area surrounding the white pixel polygon in the mask, 
    both from the image and the mask.
    
    Enlarge the crop allowing a margin both for the width and the height.
    Enlarged width will be width*crop_enlarge_width, 
    enlarged height will be height*crop_enlarge_height.
    
    Resize the cropped patch to a given size. Do not resize if any one
    of the parameters is None.
    
    Resamples patches located on a randomly selected topleft pixel, 
    both from the image and the mask (optional). Do not resample if 
    num_resample=0.
    
    Args:
        image_file (str): file path to the input image.   
        mask_file (str): file path to the binary mask image.  
        outdir: store images directory
        outfile: write each stored image name and mask name into this file.
        num_resample (int): number of random resample patches from the image and the mask.  

    Returns:
        None: Saves resulting patches into outdir

    """  
    assert os.path.exists(image_file) and os.path.isfile(image_file)
    assert os.path.exists(mask_file) and os.path.isfile(mask_file)

    img  = Image.open(image_file)
    mask = Image.open(mask_file)
    
    # get the bounding box coordinates from the mask image.
    # upperleft_x, upperleft_y, bottomright_x, and bottomright_y
    bbox = mask.getbbox()
    
    # range for cropping scale
    b=1.3
    a=1.1
    crop_enlarge_size = (b - a) * np.random.random_sample() + a

    # enlarge the bounding box with respect to given enlarging params
    old_height = bbox[3]-bbox[1]
    
    # her iki boyut en az 480 piksel olacak sekilde genislikte kes
    
    if old_height <= 480:
        new_height = 480
    else:
        new_height = int(crop_enlarge_size*old_height)
        if new_height>img.height:
            new_height=img.height
        
        
    upperleft_y = bbox[1]-int((new_height-old_height)/2.0)
    upperleft_y = 0 if upperleft_y < 0 else upperleft_y
    bottomright_y = upperleft_y + new_height
    if bottomright_y > img.height:
        upperleft_y -= (bottomright_y-img.height)
        upperleft_y = 0 if upperleft_y < 0 else upperleft_y
        bottomright_y = img.height


    old_width = bbox[2]-bbox[0]
    
    if old_width <= 480:
        new_width = 480
    else:
        new_width = int(crop_enlarge_size*old_width)
        if new_width>img.width:
            new_width=img.width
        

    upperleft_x = bbox[0]-int((new_width-old_width)/2.0)
    upperleft_x = 0 if upperleft_x < 0 else upperleft_x
    bottomright_x = upperleft_x + new_width
    bottomright_x = img.width if bottomright_x > img.width else bottomright_x
 
    if bottomright_x > img.width:
        upperleft_x -= (bottomright_x-img.height)
        upperleft_x = 0 if upperleft_x < 0 else upperleft_x
        bottomright_x = img.width

    enlarged_bbox = (upperleft_x, upperleft_y, bottomright_x, bottomright_y)
    
    if bottomright_x-upperleft_x < 480 or bottomright_y-upperleft_y < 480:        
        print(os.path.join(image_file) + " " + str(bottomright_x-upperleft_x) + " " + str(bottomright_y-upperleft_y))
        input()
    
    # crop the enlarged area from the image
    cropped_img = img.crop(enlarged_bbox)
    cropped_mask = mask.crop(enlarged_bbox)
    
    image_filename, image_file_extension = os.path.splitext(os.path.basename(image_file))
    mask_filename, mask_file_extension = os.path.splitext(os.path.basename(mask_file))
    
    cropped_img.save(os.path.join(outdir, image_filename + image_file_extension))
    cropped_mask.save(os.path.join(outdir, mask_filename + mask_file_extension))
    
    print('training: ' + os.path.basename(image_file) + " " + os.path.basename(mask_file))
    print(os.path.basename(image_file) + " " + os.path.basename(mask_file), file=train_list_file)
    
    resample_cnt=0
    if num_resample > 0:
        
        # crop another random rectangle
        for i in range(num_resample):
            
            if (new_width>=img.width) or (new_height>=img.height):
                continue
                
            if (old_width*old_height) / (img.width*img.height) > 0.6:
                continue
            
#             # initialize
#             rand_bbox_final = enlarged_bbox
#             MAX = new_height*new_width
            
#             # try 10 times, and choose the bbox that contains the max amount of bground
#             for j in range(num_trials):
#                 rand_loc_y = np.random.randint(low=0, high=img.height-new_height, size=1)[0]             
#                 rand_loc_x = np.random.randint(low=0, high=img.width-new_width, size=1)[0]
#                 rand_bbox = (rand_loc_x, rand_loc_y, rand_loc_x+new_width-1, rand_loc_y+new_height-1)
#                 cropped_mask = mask.crop(rand_bbox)
#                 num_white_pix = np.count_nonzero(np.asarray(cropped_mask))
#                 if num_white_pix < MAX:
#                     MAX = num_white_pix
#                     rand_bbox_final = rand_bbox

            rand_loc_y = np.random.randint(low=0, high=img.height-new_height, size=1)[0] 
            rand_loc_x = np.random.randint(low=0, high=img.width-new_width, size=1)[0]
            rand_bbox = (rand_loc_x, rand_loc_y, rand_loc_x+new_width, rand_loc_y+new_height)
        
        
        
            cropped_img = img.crop(rand_bbox)
            cropped_mask = mask.crop(rand_bbox)
            cropped_img.save(os.path.join(outdir, image_filename + '_{:02d}'.format(i+1) + image_file_extension))
            cropped_mask.save(os.path.join(outdir, mask_filename + '_{:02d}'.format(i+1) + mask_file_extension))
            print('training: ' + image_filename + '_{:02d}'.format(i+1) + image_file_extension + " " + mask_filename + '_{:02d}'.format(i+1) + mask_file_extension)
            print(image_filename + '_{:02d}'.format(i+1) + image_file_extension + " " + mask_filename + '_{:02d}'.format(i+1) + mask_file_extension, file=train_list_file)
            resample_cnt += 1
    
    return resample_cnt

# %% [markdown]
# ### resample subimage(s): take the bbox having max background pixels among 100 random candidates

# %%
from PIL import Image
import numpy as np
import os

def crop_resample(image_file, mask_file, outdir, outfile,
                  num_resample=1):
    """Crops a patch from a given image, and resample random patches (optional).

    Given a 2D image and binary mask image, crops the bounding box
    area surrounding the white pixel polygon in the mask, 
    both from the image and the mask.
    
    Enlarge the crop allowing a margin both for the width and the height.
    Enlarged width will be width*crop_enlarge_width, 
    enlarged height will be height*crop_enlarge_height.
    
    Resize the cropped patch to a given size. Do not resize if any one
    of the parameters is None.
    
    Resamples patches located on a randomly selected topleft pixel, 
    both from the image and the mask (optional). Do not resample if 
    num_resample=0.
    
    Args:
        image_file (str): file path to the input image.   
        mask_file (str): file path to the binary mask image.  
        outdir: store images directory
        outfile: write each stored image name and mask name into this file.
        num_resample (int): number of random resample patches from the image and the mask.  

    Returns:
        None: Saves resulting patches into outdir

    """  
    assert os.path.exists(image_file) and os.path.isfile(image_file)
    assert os.path.exists(mask_file) and os.path.isfile(mask_file)

    img  = Image.open(image_file)
    mask = Image.open(mask_file)
    
    # get the bounding box coordinates from the mask image.
    # upperleft_x, upperleft_y, bottomright_x, and bottomright_y
    bbox = mask.getbbox()
    
    # range for cropping scale
    b=1.3
    a=1.1
    crop_enlarge_size = (b - a) * np.random.random_sample() + a

    # enlarge the bounding box with respect to given enlarging params
    old_height = bbox[3]-bbox[1]
    
    # her iki boyut en az 480 piksel olacak sekilde genislikte kes
    
    if old_height <= 480:
        new_height = 480
    else:
        new_height = int(crop_enlarge_size*old_height)
        if new_height>img.height:
            new_height=img.height
        
        
    upperleft_y = bbox[1]-int((new_height-old_height)/2.0)
    upperleft_y = 0 if upperleft_y < 0 else upperleft_y
    bottomright_y = upperleft_y + new_height
    if bottomright_y > img.height:
        upperleft_y -= (bottomright_y-img.height)
        upperleft_y = 0 if upperleft_y < 0 else upperleft_y
        bottomright_y = img.height


    old_width = bbox[2]-bbox[0]
    
    if old_width <= 480:
        new_width = 480
    else:
        new_width = int(crop_enlarge_size*old_width)
        if new_width>img.width:
            new_width=img.width
        

    upperleft_x = bbox[0]-int((new_width-old_width)/2.0)
    upperleft_x = 0 if upperleft_x < 0 else upperleft_x
    bottomright_x = upperleft_x + new_width
    bottomright_x = img.width if bottomright_x > img.width else bottomright_x
 
    if bottomright_x > img.width:
        upperleft_x -= (bottomright_x-img.height)
        upperleft_x = 0 if upperleft_x < 0 else upperleft_x
        bottomright_x = img.width

    enlarged_bbox = (upperleft_x, upperleft_y, bottomright_x, bottomright_y)
    
    if bottomright_x-upperleft_x < 480 or bottomright_y-upperleft_y < 480:        
        print(os.path.join(image_file) + " " + str(bottomright_x-upperleft_x) + " " + str(bottomright_y-upperleft_y))
        input()
    
    # crop the enlarged area from the image
    cropped_img = img.crop(enlarged_bbox)
    cropped_mask = mask.crop(enlarged_bbox)
    
    image_filename, image_file_extension = os.path.splitext(os.path.basename(image_file))
    mask_filename, mask_file_extension = os.path.splitext(os.path.basename(mask_file))
    
    cropped_img.save(os.path.join(outdir, image_filename + image_file_extension))
    cropped_mask.save(os.path.join(outdir, mask_filename + mask_file_extension))
    
    print('training: ' + os.path.basename(image_file) + " " + os.path.basename(mask_file))
    print(os.path.basename(image_file) + " " + os.path.basename(mask_file), file=train_list_file)
    
    resample_cnt=0
    if num_resample > 0:
        
        # crop another random rectangle
        for i in range(num_resample):
            
            if (new_width>=img.width) or (new_height>=img.height):
                continue
                
            if (old_width*old_height) / (img.width*img.height) > 0.6:
                continue
            
            
            # initialize
            rand_bbox_final = enlarged_bbox
            MAX = new_height*new_width
            num_trials=100
            # try 10 times, and choose the bbox that contains the max amount of bground
            for j in range(num_trials):
                rand_loc_y = np.random.randint(low=0, high=img.height-new_height, size=1)[0]             
                rand_loc_x = np.random.randint(low=0, high=img.width-new_width, size=1)[0]
                rand_bbox = (rand_loc_x, rand_loc_y, rand_loc_x+new_width, rand_loc_y+new_height)
                cropped_mask = mask.crop(rand_bbox)
                num_white_pix = np.count_nonzero(np.asarray(cropped_mask))
                if num_white_pix < MAX:
                    MAX = num_white_pix
                    rand_bbox_final = rand_bbox       
    
            
            cropped_img = img.crop(rand_bbox_final)
            cropped_mask = mask.crop(rand_bbox_final)
            cropped_img.save(os.path.join(outdir, image_filename + '_{:02d}'.format(i+1) + image_file_extension))
            cropped_mask.save(os.path.join(outdir, mask_filename + '_{:02d}'.format(i+1) + mask_file_extension))
            print('training: ' + image_filename + '_{:02d}'.format(i+1) + image_file_extension + " " + mask_filename + '_{:02d}'.format(i+1) + mask_file_extension)
            print(image_filename + '_{:02d}'.format(i+1) + image_file_extension + " " + mask_filename + '_{:02d}'.format(i+1) + mask_file_extension, file=train_list_file)
            resample_cnt += 1
    
    return resample_cnt

# %%
import os
from shutil import copy
import errno

### ##################################################################### ###
### This cell performs cropping to only training samples                  ###
### Random 10% portions of the training set is left as validation set     ###
### Training and validation samples are put into training_out_dir_path    ###
### ##################################################################### ###

base_dir_path = os.path.normpath('C:/Users/kirta/Documents/research/data')

training_data_dirname = 'ISBI2016_ISIC_Part1_Training_Data'
training_data_dir_path = os.path.join(base_dir_path, training_data_dirname)

training_gt_dirname = 'ISBI2016_ISIC_Part1_Training_GroundTruth'
training_gt_dir_path = os.path.join(base_dir_path, training_gt_dirname)

training_out_dirname = 'ISBI2016_ISIC_Part1_Training_Data_v8_processed'
training_out_dir_path = os.path.join(base_dir_path, training_out_dirname)

try:
    os.makedirs(training_out_dir_path)
except OSError as e:
    if e.errno != errno.EEXIST:
        raise  # raises the error again


train_val_image_filenames=[]
for root, _, files in os.walk(training_data_dir_path):
    for name in files:
        train_val_image_filenames.append(name) 

train_val_image_filenames.sort()

train_val_mask_filenames=[]
for root, _, files in os.walk(training_gt_dir_path):
    for name in files:
        train_val_mask_filenames.append(name) 

train_val_mask_filenames.sort()


merged = list(zip(train_val_image_filenames, train_val_mask_filenames))
np.random.shuffle(merged)


# both cropping and resizing for training samples
train_list_filename = 'isbi2016_isic_part1_train_v8.list'
train_list_filepath = os.path.join(base_dir_path, train_list_filename)
train_list_file = open(train_list_filepath, 'w')

# no cropping or resizing for validation samples
val_list_filename = 'isbi2016_isic_part1_val_v8.list'
val_list_filepath = os.path.join(base_dir_path, val_list_filename)
validation_list_file = open(val_list_filepath, 'w')


num_val = int(0.1*len(train_val_image_filenames))
cnt=0
resample_cnt=0
for image_file, mask_file in merged:
    
    if cnt < num_val:
        print('validation: ' + image_file + " " + mask_file)
        print(image_file + " " + mask_file, file=validation_list_file)
        copy(os.path.join(training_data_dir_path, image_file), training_out_dir_path)
        copy(os.path.join(training_gt_dir_path, mask_file), training_out_dir_path)
    else:
        resample_cnt += crop_resample(os.path.join(training_data_dir_path, image_file), 
                      os.path.join(training_gt_dir_path, mask_file), 
                      training_out_dir_path, train_list_file)
        print('resample count: ' + str(resample_cnt))
        
    cnt += 1

train_list_file.close()
validation_list_file.close()
# Out:
# validation: ISIC_0000423.jpg ISIC_0000423_Segmentation.png
# validation: ISIC_0002093.jpg ISIC_0002093_Segmentation.png
# validation: ISIC_0009877.jpg ISIC_0009877_Segmentation.png
# validation: ISIC_0010225.jpg ISIC_0010225_Segmentation.png
# validation: ISIC_0001188.jpg ISIC_0001188_Segmentation.png
# validation: ISIC_0000385.jpg ISIC_0000385_Segmentation.png
# validation: ISIC_0009960.jpg ISIC_0009960_Segmentation.png
# validation: ISIC_0003174.jpg ISIC_0003174_Segmentation.png
# validation: ISIC_0000301.jpg ISIC_0000301_Segmentation.png
# validation: ISIC_0010380.jpg ISIC_0010380_Segmentation.png
# validation: ISIC_0000281.jpg ISIC_0000281_Segmentation.png
# validation: ISIC_0010358.jpg ISIC_0010358_Segmentation.png
# validation: ISIC_0000031.jpg ISIC_0000031_Segmentation.png
# validation: ISIC_0010558.jpg ISIC_0010558_Segmentation.png
# validation: ISIC_0011380.jpg ISIC_0011380_Segmentation.png
# validation: ISIC_0006800.jpg ISIC_0006800_Segmentation.png
# validation: ISIC_0010191.jpg ISIC_0010191_Segmentation.png
# validation: ISIC_0000370.jpg ISIC_0000370_Segmentation.png
# validation: ISIC_0000452.jpg ISIC_0000452_Segmentation.png
# validation: ISIC_0000218.jpg ISIC_0000218_Segmentation.png
# validation: ISIC_0011297.jpg ISIC_0011297_Segmentation.png
# validation: ISIC_0011315.jpg ISIC_0011315_Segmentation.png
# validation: ISIC_0000390.jpg ISIC_0000390_Segmentation.png
# validation: ISIC_0010228.jpg ISIC_0010228_Segmentation.png
# validation: ISIC_0010495.jpg ISIC_0010495_Segmentation.png
# validation: ISIC_0011130.jpg ISIC_0011130_Segmentation.png
# validation: ISIC_0009971.jpg ISIC_0009971_Segmentation.png
# validation: ISIC_0009344.jpg ISIC_0009344_Segmentation.png
# validation: ISIC_0009979.jpg ISIC_0009979_Segmentation.png
# validation: ISIC_0005639.jpg ISIC_0005639_Segmentation.png
# validation: ISIC_0001187.jpg ISIC_0001187_Segmentation.png
# validation: ISIC_0000541.jpg ISIC_0000541_Segmentation.png
# validation: ISIC_0011378.jpg ISIC_0011378_Segmentation.png
# validation: ISIC_0011199.jpg ISIC_0011199_Segmentation.png
# validation: ISIC_0000268.jpg ISIC_0000268_Segmentation.png
# validation: ISIC_0000203.jpg ISIC_0000203_Segmentation.png
# validation: ISIC_0010040.jpg ISIC_0010040_Segmentation.png
# validation: ISIC_0011125.jpg ISIC_0011125_Segmentation.png
# validation: ISIC_0010468.jpg ISIC_0010468_Segmentation.png
# validation: ISIC_0010850.jpg ISIC_0010850_Segmentation.png
# validation: ISIC_0011357.jpg ISIC_0011357_Segmentation.png
# validation: ISIC_0009949.jpg ISIC_0009949_Segmentation.png
# validation: ISIC_0011139.jpg ISIC_0011139_Segmentation.png
# validation: ISIC_0000155.jpg ISIC_0000155_Segmentation.png
# validation: ISIC_0011356.jpg ISIC_0011356_Segmentation.png
# validation: ISIC_0010361.jpg ISIC_0010361_Segmentation.png
# validation: ISIC_0010010.jpg ISIC_0010010_Segmentation.png
# validation: ISIC_0000531.jpg ISIC_0000531_Segmentation.png
# validation: ISIC_0000263.jpg ISIC_0000263_Segmentation.png
# validation: ISIC_0000145.jpg ISIC_0000145_Segmentation.png
# validation: ISIC_0009925.jpg ISIC_0009925_Segmentation.png
# validation: ISIC_0000290.jpg ISIC_0000290_Segmentation.png
# validation: ISIC_0000008.jpg ISIC_0000008_Segmentation.png
# validation: ISIC_0011339.jpg ISIC_0011339_Segmentation.png
# validation: ISIC_0000134.jpg ISIC_0000134_Segmentation.png
# validation: ISIC_0010493.jpg ISIC_0010493_Segmentation.png
# validation: ISIC_0010844.jpg ISIC_0010844_Segmentation.png
# validation: ISIC_0011229.jpg ISIC_0011229_Segmentation.png
# validation: ISIC_0000376.jpg ISIC_0000376_Segmentation.png
# validation: ISIC_0011211.jpg ISIC_0011211_Segmentation.png
# validation: ISIC_0000209.jpg ISIC_0000209_Segmentation.png
# validation: ISIC_0000439.jpg ISIC_0000439_Segmentation.png
# validation: ISIC_0000445.jpg ISIC_0000445_Segmentation.png
# validation: ISIC_0010178.jpg ISIC_0010178_Segmentation.png
# validation: ISIC_0000477.jpg ISIC_0000477_Segmentation.png
# validation: ISIC_0000119.jpg ISIC_0000119_Segmentation.png
# validation: ISIC_0010227.jpg ISIC_0010227_Segmentation.png
# validation: ISIC_0000447.jpg ISIC_0000447_Segmentation.png
# validation: ISIC_0000239.jpg ISIC_0000239_Segmentation.png
# validation: ISIC_0000285.jpg ISIC_0000285_Segmentation.png
# validation: ISIC_0009934.jpg ISIC_0009934_Segmentation.png
# validation: ISIC_0010857.jpg ISIC_0010857_Segmentation.png
# validation: ISIC_0000431.jpg ISIC_0000431_Segmentation.png
# validation: ISIC_0009911.jpg ISIC_0009911_Segmentation.png
# validation: ISIC_0011118.jpg ISIC_0011118_Segmentation.png
# validation: ISIC_0002806.jpg ISIC_0002806_Segmentation.png
# validation: ISIC_0000190.jpg ISIC_0000190_Segmentation.png
# validation: ISIC_0010575.jpg ISIC_0010575_Segmentation.png
# validation: ISIC_0009953.jpg ISIC_0009953_Segmentation.png
# validation: ISIC_0001134.jpg ISIC_0001134_Segmentation.png
# validation: ISIC_0011116.jpg ISIC_0011116_Segmentation.png
# validation: ISIC_0000184.jpg ISIC_0000184_Segmentation.png
# validation: ISIC_0011330.jpg ISIC_0011330_Segmentation.png
# validation: ISIC_0010589.jpg ISIC_0010589_Segmentation.png
# validation: ISIC_0010226.jpg ISIC_0010226_Segmentation.png
# validation: ISIC_0000206.jpg ISIC_0000206_Segmentation.png
# validation: ISIC_0010318.jpg ISIC_0010318_Segmentation.png
# validation: ISIC_0011214.jpg ISIC_0011214_Segmentation.png
# validation: ISIC_0000276.jpg ISIC_0000276_Segmentation.png
# validation: ISIC_0010168.jpg ISIC_0010168_Segmentation.png
# training: ISIC_0002780.jpg ISIC_0002780_Segmentation.png
# training: ISIC_0002780_01.jpg ISIC_0002780_Segmentation_01.png
# resample count: 1
# training: ISIC_0009860.jpg ISIC_0009860_Segmentation.png
# training: ISIC_0009860_01.jpg ISIC_0009860_Segmentation_01.png
# resample count: 2
# training: ISIC_0000091.jpg ISIC_0000091_Segmentation.png
# training: ISIC_0000091_01.jpg ISIC_0000091_Segmentation_01.png
# resample count: 3
# training: ISIC_0010351.jpg ISIC_0010351_Segmentation.png
# training: ISIC_0010351_01.jpg ISIC_0010351_Segmentation_01.png
# resample count: 4
# training: ISIC_0010593.jpg ISIC_0010593_Segmentation.png
# training: ISIC_0010593_01.jpg ISIC_0010593_Segmentation_01.png
# resample count: 5
# training: ISIC_0010003.jpg ISIC_0010003_Segmentation.png
# training: ISIC_0010003_01.jpg ISIC_0010003_Segmentation_01.png
# resample count: 6
# training: ISIC_0010435.jpg ISIC_0010435_Segmentation.png
# training: ISIC_0010435_01.jpg ISIC_0010435_Segmentation_01.png
# resample count: 7
# training: ISIC_0000249.jpg ISIC_0000249_Segmentation.png
# training: ISIC_0000249_01.jpg ISIC_0000249_Segmentation_01.png
# resample count: 8
# training: ISIC_0000124.jpg ISIC_0000124_Segmentation.png
# training: ISIC_0000124_01.jpg ISIC_0000124_Segmentation_01.png
# resample count: 9
# training: ISIC_0001133.jpg ISIC_0001133_Segmentation.png
# training: ISIC_0001133_01.jpg ISIC_0001133_Segmentation_01.png
# resample count: 10
# training: ISIC_0000252.jpg ISIC_0000252_Segmentation.png
# training: ISIC_0000252_01.jpg ISIC_0000252_Segmentation_01.png
# resample count: 11
# training: ISIC_0009900.jpg ISIC_0009900_Segmentation.png
# resample count: 11
# training: ISIC_0000397.jpg ISIC_0000397_Segmentation.png
# training: ISIC_0000397_01.jpg ISIC_0000397_Segmentation_01.png
# resample count: 12
# training: ISIC_0000104.jpg ISIC_0000104_Segmentation.png
# training: ISIC_0000104_01.jpg ISIC_0000104_Segmentation_01.png
# resample count: 13
# training: ISIC_0000183.jpg ISIC_0000183_Segmentation.png
# resample count: 13
# training: ISIC_0000364.jpg ISIC_0000364_Segmentation.png
# resample count: 13
# training: ISIC_0009896.jpg ISIC_0009896_Segmentation.png
# resample count: 13
# training: ISIC_0010046.jpg ISIC_0010046_Segmentation.png
# training: ISIC_0010046_01.jpg ISIC_0010046_Segmentation_01.png
# resample count: 14
# training: ISIC_0011402.jpg ISIC_0011402_Segmentation.png
# resample count: 14
# training: ISIC_0000382.jpg ISIC_0000382_Segmentation.png
# training: ISIC_0000382_01.jpg ISIC_0000382_Segmentation_01.png
# resample count: 15
# training: ISIC_0010239.jpg ISIC_0010239_Segmentation.png
# resample count: 15
# training: ISIC_0000093.jpg ISIC_0000093_Segmentation.png
# training: ISIC_0000093_01.jpg ISIC_0000093_Segmentation_01.png
# resample count: 16
# training: ISIC_0011352.jpg ISIC_0011352_Segmentation.png
# resample count: 16
# training: ISIC_0011135.jpg ISIC_0011135_Segmentation.png
# training: ISIC_0011135_01.jpg ISIC_0011135_Segmentation_01.png
# resample count: 17
# training: ISIC_0011296.jpg ISIC_0011296_Segmentation.png
# training: ISIC_0011296_01.jpg ISIC_0011296_Segmentation_01.png
# resample count: 18
# training: ISIC_0000363.jpg ISIC_0000363_Segmentation.png
# training: ISIC_0000363_01.jpg ISIC_0000363_Segmentation_01.png
# resample count: 19
# training: ISIC_0000109.jpg ISIC_0000109_Segmentation.png
# resample count: 19
# training: ISIC_0000412.jpg ISIC_0000412_Segmentation.png
# resample count: 19
# training: ISIC_0000075.jpg ISIC_0000075_Segmentation.png
# resample count: 19
# training: ISIC_0010554.jpg ISIC_0010554_Segmentation.png
# training: ISIC_0010554_01.jpg ISIC_0010554_Segmentation_01.png
# resample count: 20
# training: ISIC_0000171.jpg ISIC_0000171_Segmentation.png
# resample count: 20
# training: ISIC_0000444.jpg ISIC_0000444_Segmentation.png
# training: ISIC_0000444_01.jpg ISIC_0000444_Segmentation_01.png
# resample count: 21
# training: ISIC_0010066.jpg ISIC_0010066_Segmentation.png
# training: ISIC_0010066_01.jpg ISIC_0010066_Segmentation_01.png
# resample count: 22
# training: ISIC_0010036.jpg ISIC_0010036_Segmentation.png
# resample count: 22
# training: ISIC_0010337.jpg ISIC_0010337_Segmentation.png
# training: ISIC_0010337_01.jpg ISIC_0010337_Segmentation_01.png
# resample count: 23
# training: ISIC_0011124.jpg ISIC_0011124_Segmentation.png
# training: ISIC_0011124_01.jpg ISIC_0011124_Segmentation_01.png
# resample count: 24
# training: ISIC_0000225.jpg ISIC_0000225_Segmentation.png
# training: ISIC_0000225_01.jpg ISIC_0000225_Segmentation_01.png
# resample count: 25
# training: ISIC_0001119.jpg ISIC_0001119_Segmentation.png
# training: ISIC_0001119_01.jpg ISIC_0001119_Segmentation_01.png
# resample count: 26
# training: ISIC_0010185.jpg ISIC_0010185_Segmentation.png
# training: ISIC_0010185_01.jpg ISIC_0010185_Segmentation_01.png
# resample count: 27
# training: ISIC_0010056.jpg ISIC_0010056_Segmentation.png
# resample count: 27
# training: ISIC_0011217.jpg ISIC_0011217_Segmentation.png
# training: ISIC_0011217_01.jpg ISIC_0011217_Segmentation_01.png
# resample count: 28
# training: ISIC_0003308.jpg ISIC_0003308_Segmentation.png
# training: ISIC_0003308_01.jpg ISIC_0003308_Segmentation_01.png
# resample count: 29
# training: ISIC_0010205.jpg ISIC_0010205_Segmentation.png
# training: ISIC_0010205_01.jpg ISIC_0010205_Segmentation_01.png
# resample count: 30
# training: ISIC_0011166.jpg ISIC_0011166_Segmentation.png
# training: ISIC_0011166_01.jpg ISIC_0011166_Segmentation_01.png
# resample count: 31
# training: ISIC_0000425.jpg ISIC_0000425_Segmentation.png
# resample count: 31
# training: ISIC_0011137.jpg ISIC_0011137_Segmentation.png
# training: ISIC_0011137_01.jpg ISIC_0011137_Segmentation_01.png
# resample count: 32
# training: ISIC_0000028.jpg ISIC_0000028_Segmentation.png
# training: ISIC_0000028_01.jpg ISIC_0000028_Segmentation_01.png
# resample count: 33
# training: ISIC_0011156.jpg ISIC_0011156_Segmentation.png
# resample count: 33
# training: ISIC_0001152.jpg ISIC_0001152_Segmentation.png
# resample count: 33
# training: ISIC_0000150.jpg ISIC_0000150_Segmentation.png
# training: ISIC_0000150_01.jpg ISIC_0000150_Segmentation_01.png
# resample count: 34
# training: ISIC_0008029.jpg ISIC_0008029_Segmentation.png
# training: ISIC_0008029_01.jpg ISIC_0008029_Segmentation_01.png
# resample count: 35
# training: ISIC_0001449.jpg ISIC_0001449_Segmentation.png
# training: ISIC_0001449_01.jpg ISIC_0001449_Segmentation_01.png
# resample count: 36
# training: ISIC_0005548.jpg ISIC_0005548_Segmentation.png
# training: ISIC_0005548_01.jpg ISIC_0005548_Segmentation_01.png
# resample count: 37
# training: ISIC_0000331.jpg ISIC_0000331_Segmentation.png
# training: ISIC_0000331_01.jpg ISIC_0000331_Segmentation_01.png
# resample count: 38
# training: ISIC_0010370.jpg ISIC_0010370_Segmentation.png
# training: ISIC_0010370_01.jpg ISIC_0010370_Segmentation_01.png
# resample count: 39
# training: ISIC_0002459.jpg ISIC_0002459_Segmentation.png
# training: ISIC_0002459_01.jpg ISIC_0002459_Segmentation_01.png
# resample count: 40
# training: ISIC_0010357.jpg ISIC_0010357_Segmentation.png
# training: ISIC_0010357_01.jpg ISIC_0010357_Segmentation_01.png
# resample count: 41
# training: ISIC_0000352.jpg ISIC_0000352_Segmentation.png
# training: ISIC_0000352_01.jpg ISIC_0000352_Segmentation_01.png
# resample count: 42
# training: ISIC_0000396.jpg ISIC_0000396_Segmentation.png
# training: ISIC_0000396_01.jpg ISIC_0000396_Segmentation_01.png
# resample count: 43
# training: ISIC_0000019.jpg ISIC_0000019_Segmentation.png
# training: ISIC_0000019_01.jpg ISIC_0000019_Segmentation_01.png
# resample count: 44
# training: ISIC_0011326.jpg ISIC_0011326_Segmentation.png
# training: ISIC_0011326_01.jpg ISIC_0011326_Segmentation_01.png
# resample count: 45
# training: ISIC_0007038.jpg ISIC_0007038_Segmentation.png
# training: ISIC_0007038_01.jpg ISIC_0007038_Segmentation_01.png
# resample count: 46
# training: ISIC_0010568.jpg ISIC_0010568_Segmentation.png
# resample count: 46
# training: ISIC_0002438.jpg ISIC_0002438_Segmentation.png
# training: ISIC_0002438_01.jpg ISIC_0002438_Segmentation_01.png
# resample count: 47
# training: ISIC_0000265.jpg ISIC_0000265_Segmentation.png
# training: ISIC_0000265_01.jpg ISIC_0000265_Segmentation_01.png
# resample count: 48
# training: ISIC_0010203.jpg ISIC_0010203_Segmentation.png
# training: ISIC_0010203_01.jpg ISIC_0010203_Segmentation_01.png
# resample count: 49
# training: ISIC_0010488.jpg ISIC_0010488_Segmentation.png
# training: ISIC_0010488_01.jpg ISIC_0010488_Segmentation_01.png
# resample count: 50
# training: ISIC_0011100.jpg ISIC_0011100_Segmentation.png
# training: ISIC_0011100_01.jpg ISIC_0011100_Segmentation_01.png
# resample count: 51
# training: ISIC_0011102.jpg ISIC_0011102_Segmentation.png
# training: ISIC_0011102_01.jpg ISIC_0011102_Segmentation_01.png
# resample count: 52
# training: ISIC_0001306.jpg ISIC_0001306_Segmentation.png
# training: ISIC_0001306_01.jpg ISIC_0001306_Segmentation_01.png
# resample count: 53
# training: ISIC_0010603.jpg ISIC_0010603_Segmentation.png
# resample count: 53
# training: ISIC_0008236.jpg ISIC_0008236_Segmentation.png
# training: ISIC_0008236_01.jpg ISIC_0008236_Segmentation_01.png
# resample count: 54
# training: ISIC_0000546.jpg ISIC_0000546_Segmentation.png
# training: ISIC_0000546_01.jpg ISIC_0000546_Segmentation_01.png
# resample count: 55
# training: ISIC_0000082.jpg ISIC_0000082_Segmentation.png
# training: ISIC_0000082_01.jpg ISIC_0000082_Segmentation_01.png
# resample count: 56
# training: ISIC_0009871.jpg ISIC_0009871_Segmentation.png
# training: ISIC_0009871_01.jpg ISIC_0009871_Segmentation_01.png
# resample count: 57
# training: ISIC_0000882.jpg ISIC_0000882_Segmentation.png
# training: ISIC_0000882_01.jpg ISIC_0000882_Segmentation_01.png
# resample count: 58
# training: ISIC_0009430.jpg ISIC_0009430_Segmentation.png
# training: ISIC_0009430_01.jpg ISIC_0009430_Segmentation_01.png
# resample count: 59
# training: ISIC_0010341.jpg ISIC_0010341_Segmentation.png
# training: ISIC_0010341_01.jpg ISIC_0010341_Segmentation_01.png
# resample count: 60
# training: ISIC_0002489.jpg ISIC_0002489_Segmentation.png
# training: ISIC_0002489_01.jpg ISIC_0002489_Segmentation_01.png
# resample count: 61
# training: ISIC_0000322.jpg ISIC_0000322_Segmentation.png
# training: ISIC_0000322_01.jpg ISIC_0000322_Segmentation_01.png
# resample count: 62
# training: ISIC_0010000.jpg ISIC_0010000_Segmentation.png
# resample count: 62
# training: ISIC_0010182.jpg ISIC_0010182_Segmentation.png
# training: ISIC_0010182_01.jpg ISIC_0010182_Segmentation_01.png
# resample count: 63
# training: ISIC_0011105.jpg ISIC_0011105_Segmentation.png
# resample count: 63
# training: ISIC_0000536.jpg ISIC_0000536_Segmentation.png
# training: ISIC_0000536_01.jpg ISIC_0000536_Segmentation_01.png
# resample count: 64
# training: ISIC_0010091.jpg ISIC_0010091_Segmentation.png
# resample count: 64
# training: ISIC_0000461.jpg ISIC_0000461_Segmentation.png
# training: ISIC_0000461_01.jpg ISIC_0000461_Segmentation_01.png
# resample count: 65
# training: ISIC_0000026.jpg ISIC_0000026_Segmentation.png
# resample count: 65
# training: ISIC_0000085.jpg ISIC_0000085_Segmentation.png
# training: ISIC_0000085_01.jpg ISIC_0000085_Segmentation_01.png
# resample count: 66
# training: ISIC_0011084.jpg ISIC_0011084_Segmentation.png
# training: ISIC_0011084_01.jpg ISIC_0011084_Segmentation_01.png
# resample count: 67
# training: ISIC_0002616.jpg ISIC_0002616_Segmentation.png
# training: ISIC_0002616_01.jpg ISIC_0002616_Segmentation_01.png
# resample count: 68
# training: ISIC_0011372.jpg ISIC_0011372_Segmentation.png
# training: ISIC_0011372_01.jpg ISIC_0011372_Segmentation_01.png
# resample count: 69
# training: ISIC_0000314.jpg ISIC_0000314_Segmentation.png
# training: ISIC_0000314_01.jpg ISIC_0000314_Segmentation_01.png
# resample count: 70
# training: ISIC_0011353.jpg ISIC_0011353_Segmentation.png
# training: ISIC_0011353_01.jpg ISIC_0011353_Segmentation_01.png
# resample count: 71
# training: ISIC_0000269.jpg ISIC_0000269_Segmentation.png
# training: ISIC_0000269_01.jpg ISIC_0000269_Segmentation_01.png
# resample count: 72
# training: ISIC_0000500.jpg ISIC_0000500_Segmentation.png
# training: ISIC_0000500_01.jpg ISIC_0000500_Segmentation_01.png
# resample count: 73
# training: ISIC_0010442.jpg ISIC_0010442_Segmentation.png
# training: ISIC_0010442_01.jpg ISIC_0010442_Segmentation_01.png
# resample count: 74
# training: ISIC_0000189.jpg ISIC_0000189_Segmentation.png
# resample count: 74
# training: ISIC_0009188.jpg ISIC_0009188_Segmentation.png
# training: ISIC_0009188_01.jpg ISIC_0009188_Segmentation_01.png
# resample count: 75
# training: ISIC_0008294.jpg ISIC_0008294_Segmentation.png
# training: ISIC_0008294_01.jpg ISIC_0008294_Segmentation_01.png
# resample count: 76
# training: ISIC_0001385.jpg ISIC_0001385_Segmentation.png
# training: ISIC_0001385_01.jpg ISIC_0001385_Segmentation_01.png
# resample count: 77
# training: ISIC_0011345.jpg ISIC_0011345_Segmentation.png
# training: ISIC_0011345_01.jpg ISIC_0011345_Segmentation_01.png
# resample count: 78
# training: ISIC_0009937.jpg ISIC_0009937_Segmentation.png
# training: ISIC_0009937_01.jpg ISIC_0009937_Segmentation_01.png
# resample count: 79
# training: ISIC_0010067.jpg ISIC_0010067_Segmentation.png
# training: ISIC_0010067_01.jpg ISIC_0010067_Segmentation_01.png
# resample count: 80
# training: ISIC_0003346.jpg ISIC_0003346_Segmentation.png
# training: ISIC_0003346_01.jpg ISIC_0003346_Segmentation_01.png
# resample count: 81
# training: ISIC_0000403.jpg ISIC_0000403_Segmentation.png
# training: ISIC_0000403_01.jpg ISIC_0000403_Segmentation_01.png
# resample count: 82
# training: ISIC_0009944.jpg ISIC_0009944_Segmentation.png
# training: ISIC_0009944_01.jpg ISIC_0009944_Segmentation_01.png
# resample count: 83
# training: ISIC_0010572.jpg ISIC_0010572_Segmentation.png
# resample count: 83
# training: ISIC_0000475.jpg ISIC_0000475_Segmentation.png
# resample count: 83
# training: ISIC_0000166.jpg ISIC_0000166_Segmentation.png
# resample count: 83
# training: ISIC_0011159.jpg ISIC_0011159_Segmentation.png
# resample count: 83
# training: ISIC_0010219.jpg ISIC_0010219_Segmentation.png
# training: ISIC_0010219_01.jpg ISIC_0010219_Segmentation_01.png
# resample count: 84
# training: ISIC_0010590.jpg ISIC_0010590_Segmentation.png
# training: ISIC_0010590_01.jpg ISIC_0010590_Segmentation_01.png
# resample count: 85
# training: ISIC_0000556.jpg ISIC_0000556_Segmentation.png
# resample count: 85
# training: ISIC_0000409.jpg ISIC_0000409_Segmentation.png
# training: ISIC_0000409_01.jpg ISIC_0000409_Segmentation_01.png
# resample count: 86
# training: ISIC_0000007.jpg ISIC_0000007_Segmentation.png
# training: ISIC_0000007_01.jpg ISIC_0000007_Segmentation_01.png
# resample count: 87
# training: ISIC_0000044.jpg ISIC_0000044_Segmentation.png
# resample count: 87
# training: ISIC_0010329.jpg ISIC_0010329_Segmentation.png
# resample count: 87
# training: ISIC_0010586.jpg ISIC_0010586_Segmentation.png
# training: ISIC_0010586_01.jpg ISIC_0010586_Segmentation_01.png
# resample count: 88
# training: ISIC_0009973.jpg ISIC_0009973_Segmentation.png
# training: ISIC_0009973_01.jpg ISIC_0009973_Segmentation_01.png
# resample count: 89
# training: ISIC_0000042.jpg ISIC_0000042_Segmentation.png
# resample count: 89
# training: ISIC_0009963.jpg ISIC_0009963_Segmentation.png
# training: ISIC_0009963_01.jpg ISIC_0009963_Segmentation_01.png
# resample count: 90
# training: ISIC_0010466.jpg ISIC_0010466_Segmentation.png
# training: ISIC_0010466_01.jpg ISIC_0010466_Segmentation_01.png
# resample count: 91
# training: ISIC_0010230.jpg ISIC_0010230_Segmentation.png
# training: ISIC_0010230_01.jpg ISIC_0010230_Segmentation_01.png
# resample count: 92
# training: ISIC_0000458.jpg ISIC_0000458_Segmentation.png
# training: ISIC_0000458_01.jpg ISIC_0000458_Segmentation_01.png
# resample count: 93
# training: ISIC_0009940.jpg ISIC_0009940_Segmentation.png
# resample count: 93
# training: ISIC_0000220.jpg ISIC_0000220_Segmentation.png
# training: ISIC_0000220_01.jpg ISIC_0000220_Segmentation_01.png
# resample count: 94
# training: ISIC_0004168.jpg ISIC_0004168_Segmentation.png
# training: ISIC_0004168_01.jpg ISIC_0004168_Segmentation_01.png
# resample count: 95
# training: ISIC_0010605.jpg ISIC_0010605_Segmentation.png
# resample count: 95
# training: ISIC_0000133.jpg ISIC_0000133_Segmentation.png
# training: ISIC_0000133_01.jpg ISIC_0000133_Segmentation_01.png
# resample count: 96
# training: ISIC_0000372.jpg ISIC_0000372_Segmentation.png
# training: ISIC_0000372_01.jpg ISIC_0000372_Segmentation_01.png
# resample count: 97
# training: ISIC_0000240.jpg ISIC_0000240_Segmentation.png
# training: ISIC_0000240_01.jpg ISIC_0000240_Segmentation_01.png
# resample count: 98
# training: ISIC_0010232.jpg ISIC_0010232_Segmentation.png
# resample count: 98
# training: ISIC_0000347.jpg ISIC_0000347_Segmentation.png
# training: ISIC_0000347_01.jpg ISIC_0000347_Segmentation_01.png
# resample count: 99
# training: ISIC_0011119.jpg ISIC_0011119_Segmentation.png
# training: ISIC_0011119_01.jpg ISIC_0011119_Segmentation_01.png
# resample count: 100
# training: ISIC_0000120.jpg ISIC_0000120_Segmentation.png
# resample count: 100
# training: ISIC_0010436.jpg ISIC_0010436_Segmentation.png
# training: ISIC_0010436_01.jpg ISIC_0010436_Segmentation_01.png
# resample count: 101
# training: ISIC_0000542.jpg ISIC_0000542_Segmentation.png
# resample count: 101
# training: ISIC_0011347.jpg ISIC_0011347_Segmentation.png
# resample count: 101
# training: ISIC_0000491.jpg ISIC_0000491_Segmentation.png
# resample count: 101
# training: ISIC_0011362.jpg ISIC_0011362_Segmentation.png
# training: ISIC_0011362_01.jpg ISIC_0011362_Segmentation_01.png
# resample count: 102
# training: ISIC_0000516.jpg ISIC_0000516_Segmentation.png
# resample count: 102
# training: ISIC_0010471.jpg ISIC_0010471_Segmentation.png
# training: ISIC_0010471_01.jpg ISIC_0010471_Segmentation_01.png
# resample count: 103
# training: ISIC_0000300.jpg ISIC_0000300_Segmentation.png
# resample count: 103
# training: ISIC_0010021.jpg ISIC_0010021_Segmentation.png
# resample count: 103
# training: ISIC_0000455.jpg ISIC_0000455_Segmentation.png
# training: ISIC_0000455_01.jpg ISIC_0000455_Segmentation_01.png
# resample count: 104
# training: ISIC_0000489.jpg ISIC_0000489_Segmentation.png
# resample count: 104
# training: ISIC_0000127.jpg ISIC_0000127_Segmentation.png
# resample count: 104
# training: ISIC_0010102.jpg ISIC_0010102_Segmentation.png
# training: ISIC_0010102_01.jpg ISIC_0010102_Segmentation_01.png
# resample count: 105
# training: ISIC_0009599.jpg ISIC_0009599_Segmentation.png
# training: ISIC_0009599_01.jpg ISIC_0009599_Segmentation_01.png
# resample count: 106
# training: ISIC_0010371.jpg ISIC_0010371_Segmentation.png
# training: ISIC_0010371_01.jpg ISIC_0010371_Segmentation_01.png
# resample count: 107
# training: ISIC_0009909.jpg ISIC_0009909_Segmentation.png
# training: ISIC_0009909_01.jpg ISIC_0009909_Segmentation_01.png
# resample count: 108
# training: ISIC_0011350.jpg ISIC_0011350_Segmentation.png
# resample count: 108
# training: ISIC_0010169.jpg ISIC_0010169_Segmentation.png
# resample count: 108
# training: ISIC_0000156.jpg ISIC_0000156_Segmentation.png
# resample count: 108
# training: ISIC_0010070.jpg ISIC_0010070_Segmentation.png
# training: ISIC_0010070_01.jpg ISIC_0010070_Segmentation_01.png
# resample count: 109
# training: ISIC_0010445.jpg ISIC_0010445_Segmentation.png
# training: ISIC_0010445_01.jpg ISIC_0010445_Segmentation_01.png
# resample count: 110
# training: ISIC_0000192.jpg ISIC_0000192_Segmentation.png
# resample count: 110
# training: ISIC_0010263.jpg ISIC_0010263_Segmentation.png
# training: ISIC_0010263_01.jpg ISIC_0010263_Segmentation_01.png
# resample count: 111
# training: ISIC_0000159.jpg ISIC_0000159_Segmentation.png
# resample count: 111
# training: ISIC_0000329.jpg ISIC_0000329_Segmentation.png
# training: ISIC_0000329_01.jpg ISIC_0000329_Segmentation_01.png
# resample count: 112
# training: ISIC_0010220.jpg ISIC_0010220_Segmentation.png
# training: ISIC_0010220_01.jpg ISIC_0010220_Segmentation_01.png
# resample count: 113
# training: ISIC_0000244.jpg ISIC_0000244_Segmentation.png
# resample count: 113
# training: ISIC_0000260.jpg ISIC_0000260_Segmentation.png
# training: ISIC_0000260_01.jpg ISIC_0000260_Segmentation_01.png
# resample count: 114
# training: ISIC_0001163.jpg ISIC_0001163_Segmentation.png
# training: ISIC_0001163_01.jpg ISIC_0001163_Segmentation_01.png
# resample count: 115
# training: ISIC_0000006.jpg ISIC_0000006_Segmentation.png
# training: ISIC_0000006_01.jpg ISIC_0000006_Segmentation_01.png
# resample count: 116
# training: ISIC_0010057.jpg ISIC_0010057_Segmentation.png
# resample count: 116
# training: ISIC_0000522.jpg ISIC_0000522_Segmentation.png
# resample count: 116
# training: ISIC_0010480.jpg ISIC_0010480_Segmentation.png
# training: ISIC_0010480_01.jpg ISIC_0010480_Segmentation_01.png
# resample count: 117
# training: ISIC_0000137.jpg ISIC_0000137_Segmentation.png
# training: ISIC_0000137_01.jpg ISIC_0000137_Segmentation_01.png
# resample count: 118
# training: ISIC_0010320.jpg ISIC_0010320_Segmentation.png
# resample count: 118
# training: ISIC_0010233.jpg ISIC_0010233_Segmentation.png
# training: ISIC_0010233_01.jpg ISIC_0010233_Segmentation_01.png
# resample count: 119
# training: ISIC_0010081.jpg ISIC_0010081_Segmentation.png
# training: ISIC_0010081_01.jpg ISIC_0010081_Segmentation_01.png
# resample count: 120
# training: ISIC_0010177.jpg ISIC_0010177_Segmentation.png
# training: ISIC_0010177_01.jpg ISIC_0010177_Segmentation_01.png
# resample count: 121
# training: ISIC_0002836.jpg ISIC_0002836_Segmentation.png
# training: ISIC_0002836_01.jpg ISIC_0002836_Segmentation_01.png
# resample count: 122
# training: ISIC_0011230.jpg ISIC_0011230_Segmentation.png
# training: ISIC_0011230_01.jpg ISIC_0011230_Segmentation_01.png
# resample count: 123
# training: ISIC_0000205.jpg ISIC_0000205_Segmentation.png
# resample count: 123
# training: ISIC_0000018.jpg ISIC_0000018_Segmentation.png
# training: ISIC_0000018_01.jpg ISIC_0000018_Segmentation_01.png
# resample count: 124
# training: ISIC_0010249.jpg ISIC_0010249_Segmentation.png
# resample count: 124
# training: ISIC_0010858.jpg ISIC_0010858_Segmentation.png
# training: ISIC_0010858_01.jpg ISIC_0010858_Segmentation_01.png
# resample count: 125
# training: ISIC_0010848.jpg ISIC_0010848_Segmentation.png
# training: ISIC_0010848_01.jpg ISIC_0010848_Segmentation_01.png
# resample count: 126
# training: ISIC_0000139.jpg ISIC_0000139_Segmentation.png
# training: ISIC_0000139_01.jpg ISIC_0000139_Segmentation_01.png
# resample count: 127
# training: ISIC_0001191.jpg ISIC_0001191_Segmentation.png
# training: ISIC_0001191_01.jpg ISIC_0001191_Segmentation_01.png
# resample count: 128
# training: ISIC_0010052.jpg ISIC_0010052_Segmentation.png
# training: ISIC_0010052_01.jpg ISIC_0010052_Segmentation_01.png
# resample count: 129
# training: ISIC_0000247.jpg ISIC_0000247_Segmentation.png
# training: ISIC_0000247_01.jpg ISIC_0000247_Segmentation_01.png
# resample count: 130
# training: ISIC_0011218.jpg ISIC_0011218_Segmentation.png
# training: ISIC_0011218_01.jpg ISIC_0011218_Segmentation_01.png
# resample count: 131
# training: ISIC_0011295.jpg ISIC_0011295_Segmentation.png
# resample count: 131
# training: ISIC_0000353.jpg ISIC_0000353_Segmentation.png
# training: ISIC_0000353_01.jpg ISIC_0000353_Segmentation_01.png
# resample count: 132
# training: ISIC_0010184.jpg ISIC_0010184_Segmentation.png
# training: ISIC_0010184_01.jpg ISIC_0010184_Segmentation_01.png
# resample count: 133
# training: ISIC_0000009.jpg ISIC_0000009_Segmentation.png
# training: ISIC_0000009_01.jpg ISIC_0000009_Segmentation_01.png
# resample count: 134
# training: ISIC_0000365.jpg ISIC_0000365_Segmentation.png
# training: ISIC_0000365_01.jpg ISIC_0000365_Segmentation_01.png
# resample count: 135
# training: ISIC_0010262.jpg ISIC_0010262_Segmentation.png
# training: ISIC_0010262_01.jpg ISIC_0010262_Segmentation_01.png
# resample count: 136
# training: ISIC_0000146.jpg ISIC_0000146_Segmentation.png
# training: ISIC_0000146_01.jpg ISIC_0000146_Segmentation_01.png
# resample count: 137
# training: ISIC_0000513.jpg ISIC_0000513_Segmentation.png
# training: ISIC_0000513_01.jpg ISIC_0000513_Segmentation_01.png
# resample count: 138
# training: ISIC_0000029.jpg ISIC_0000029_Segmentation.png
# resample count: 138
# training: ISIC_0006021.jpg ISIC_0006021_Segmentation.png
# training: ISIC_0006021_01.jpg ISIC_0006021_Segmentation_01.png
# resample count: 139
# training: ISIC_0011212.jpg ISIC_0011212_Segmentation.png
# resample count: 139
# training: ISIC_0010015.jpg ISIC_0010015_Segmentation.png
# resample count: 139
# training: ISIC_0000355.jpg ISIC_0000355_Segmentation.png
# resample count: 139
# training: ISIC_0011332.jpg ISIC_0011332_Segmentation.png
# resample count: 139
# training: ISIC_0010324.jpg ISIC_0010324_Segmentation.png
# resample count: 139
# training: ISIC_0011358.jpg ISIC_0011358_Segmentation.png
# training: ISIC_0011358_01.jpg ISIC_0011358_Segmentation_01.png
# resample count: 140
# training: ISIC_0000524.jpg ISIC_0000524_Segmentation.png
# training: ISIC_0000524_01.jpg ISIC_0000524_Segmentation_01.png
# resample count: 141
# training: ISIC_0011341.jpg ISIC_0011341_Segmentation.png
# training: ISIC_0011341_01.jpg ISIC_0011341_Segmentation_01.png
# resample count: 142
# training: ISIC_0010864.jpg ISIC_0010864_Segmentation.png
# training: ISIC_0010864_01.jpg ISIC_0010864_Segmentation_01.png
# resample count: 143
# training: ISIC_0009758.jpg ISIC_0009758_Segmentation.png
# training: ISIC_0009758_01.jpg ISIC_0009758_Segmentation_01.png
# resample count: 144
# training: ISIC_0010086.jpg ISIC_0010086_Segmentation.png
# training: ISIC_0010086_01.jpg ISIC_0010086_Segmentation_01.png
# resample count: 145
# training: ISIC_0000507.jpg ISIC_0000507_Segmentation.png
# training: ISIC_0000507_01.jpg ISIC_0000507_Segmentation_01.png
# resample count: 146
# training: ISIC_0010853.jpg ISIC_0010853_Segmentation.png
# training: ISIC_0010853_01.jpg ISIC_0010853_Segmentation_01.png
# resample count: 147
# training: ISIC_0010051.jpg ISIC_0010051_Segmentation.png
# resample count: 147
# training: ISIC_0000103.jpg ISIC_0000103_Segmentation.png
# training: ISIC_0000103_01.jpg ISIC_0000103_Segmentation_01.png
# resample count: 148
# training: ISIC_0000495.jpg ISIC_0000495_Segmentation.png
# training: ISIC_0000495_01.jpg ISIC_0000495_Segmentation_01.png
# resample count: 149
# training: ISIC_0000261.jpg ISIC_0000261_Segmentation.png
# training: ISIC_0000261_01.jpg ISIC_0000261_Segmentation_01.png
# resample count: 150
# training: ISIC_0000095.jpg ISIC_0000095_Segmentation.png
# training: ISIC_0000095_01.jpg ISIC_0000095_Segmentation_01.png
# resample count: 151
# training: ISIC_0000436.jpg ISIC_0000436_Segmentation.png
# resample count: 151
# training: ISIC_0011210.jpg ISIC_0011210_Segmentation.png
# training: ISIC_0011210_01.jpg ISIC_0011210_Segmentation_01.png
# resample count: 152
# training: ISIC_0000058.jpg ISIC_0000058_Segmentation.png
# resample count: 152
# training: ISIC_0000457.jpg ISIC_0000457_Segmentation.png
# resample count: 152
# training: ISIC_0000030.jpg ISIC_0000030_Segmentation.png
# resample count: 152
# training: ISIC_0003051.jpg ISIC_0003051_Segmentation.png
# training: ISIC_0003051_01.jpg ISIC_0003051_Segmentation_01.png
# resample count: 153
# training: ISIC_0010461.jpg ISIC_0010461_Segmentation.png
# training: ISIC_0010461_01.jpg ISIC_0010461_Segmentation_01.png
# resample count: 154
# training: ISIC_0000297.jpg ISIC_0000297_Segmentation.png
# training: ISIC_0000297_01.jpg ISIC_0000297_Segmentation_01.png
# resample count: 155
# training: ISIC_0010862.jpg ISIC_0010862_Segmentation.png
# training: ISIC_0010862_01.jpg ISIC_0010862_Segmentation_01.png
# resample count: 156
# training: ISIC_0000330.jpg ISIC_0000330_Segmentation.png
# training: ISIC_0000330_01.jpg ISIC_0000330_Segmentation_01.png
# resample count: 157
# training: ISIC_0000465.jpg ISIC_0000465_Segmentation.png
# training: ISIC_0000465_01.jpg ISIC_0000465_Segmentation_01.png
# resample count: 158
# training: ISIC_0010017.jpg ISIC_0010017_Segmentation.png
# training: ISIC_0010017_01.jpg ISIC_0010017_Segmentation_01.png
# resample count: 159
# training: ISIC_0001126.jpg ISIC_0001126_Segmentation.png
# training: ISIC_0001126_01.jpg ISIC_0001126_Segmentation_01.png
# resample count: 160
# training: ISIC_0011099.jpg ISIC_0011099_Segmentation.png
# training: ISIC_0011099_01.jpg ISIC_0011099_Segmentation_01.png
# resample count: 161
# training: ISIC_0000474.jpg ISIC_0000474_Segmentation.png
# resample count: 161
# training: ISIC_0000421.jpg ISIC_0000421_Segmentation.png
# training: ISIC_0000421_01.jpg ISIC_0000421_Segmentation_01.png
# resample count: 162
# training: ISIC_0000050.jpg ISIC_0000050_Segmentation.png
# training: ISIC_0000050_01.jpg ISIC_0000050_Segmentation_01.png
# resample count: 163
# training: ISIC_0010496.jpg ISIC_0010496_Segmentation.png
# resample count: 163
# training: ISIC_0000493.jpg ISIC_0000493_Segmentation.png
# resample count: 163
# training: ISIC_0000229.jpg ISIC_0000229_Segmentation.png
# resample count: 163
# training: ISIC_0010595.jpg ISIC_0010595_Segmentation.png
# resample count: 163
# training: ISIC_0000521.jpg ISIC_0000521_Segmentation.png
# resample count: 163
# training: ISIC_0011120.jpg ISIC_0011120_Segmentation.png
# resample count: 163
# training: ISIC_0011366.jpg ISIC_0011366_Segmentation.png
# training: ISIC_0011366_01.jpg ISIC_0011366_Segmentation_01.png
# resample count: 164
# training: ISIC_0000528.jpg ISIC_0000528_Segmentation.png
# training: ISIC_0000528_01.jpg ISIC_0000528_Segmentation_01.png
# resample count: 165
# training: ISIC_0002374.jpg ISIC_0002374_Segmentation.png
# training: ISIC_0002374_01.jpg ISIC_0002374_Segmentation_01.png
# resample count: 166
# training: ISIC_0000369.jpg ISIC_0000369_Segmentation.png
# resample count: 166
# training: ISIC_0001742.jpg ISIC_0001742_Segmentation.png
# training: ISIC_0001742_01.jpg ISIC_0001742_Segmentation_01.png
# resample count: 167
# training: ISIC_0011128.jpg ISIC_0011128_Segmentation.png
# resample count: 167
# training: ISIC_0000264.jpg ISIC_0000264_Segmentation.png
# resample count: 167
# training: ISIC_0009895.jpg ISIC_0009895_Segmentation.png
# training: ISIC_0009895_01.jpg ISIC_0009895_Segmentation_01.png
# resample count: 168
# training: ISIC_0011121.jpg ISIC_0011121_Segmentation.png
# resample count: 168
# training: ISIC_0000112.jpg ISIC_0000112_Segmentation.png
# training: ISIC_0000112_01.jpg ISIC_0000112_Segmentation_01.png
# resample count: 169
# training: ISIC_0009935.jpg ISIC_0009935_Segmentation.png
# training: ISIC_0009935_01.jpg ISIC_0009935_Segmentation_01.png
# resample count: 170
# training: ISIC_0009904.jpg ISIC_0009904_Segmentation.png
# resample count: 170
# training: ISIC_0000216.jpg ISIC_0000216_Segmentation.png
# resample count: 170
# training: ISIC_0011165.jpg ISIC_0011165_Segmentation.png
# training: ISIC_0011165_01.jpg ISIC_0011165_Segmentation_01.png
# resample count: 171
# training: ISIC_0010557.jpg ISIC_0010557_Segmentation.png
# training: ISIC_0010557_01.jpg ISIC_0010557_Segmentation_01.png
# resample count: 172
# training: ISIC_0000122.jpg ISIC_0000122_Segmentation.png
# training: ISIC_0000122_01.jpg ISIC_0000122_Segmentation_01.png
# resample count: 173
# training: ISIC_0010570.jpg ISIC_0010570_Segmentation.png
# resample count: 173
# training: ISIC_0010476.jpg ISIC_0010476_Segmentation.png
# training: ISIC_0010476_01.jpg ISIC_0010476_Segmentation_01.png
# resample count: 174
# training: ISIC_0000035.jpg ISIC_0000035_Segmentation.png
# resample count: 174
# training: ISIC_0000408.jpg ISIC_0000408_Segmentation.png
# resample count: 174
# training: ISIC_0000468.jpg ISIC_0000468_Segmentation.png
# resample count: 174
# training: ISIC_0009938.jpg ISIC_0009938_Segmentation.png
# training: ISIC_0009938_01.jpg ISIC_0009938_Segmentation_01.png
# resample count: 175
# training: ISIC_0009987.jpg ISIC_0009987_Segmentation.png
# training: ISIC_0009987_01.jpg ISIC_0009987_Segmentation_01.png
# resample count: 176
# training: ISIC_0000366.jpg ISIC_0000366_Segmentation.png
# training: ISIC_0000366_01.jpg ISIC_0000366_Segmentation_01.png
# resample count: 177
# training: ISIC_0011215.jpg ISIC_0011215_Segmentation.png
# training: ISIC_0011215_01.jpg ISIC_0011215_Segmentation_01.png
# resample count: 178
# training: ISIC_0006350.jpg ISIC_0006350_Segmentation.png
# training: ISIC_0006350_01.jpg ISIC_0006350_Segmentation_01.png
# resample count: 179
# training: ISIC_0010241.jpg ISIC_0010241_Segmentation.png
# training: ISIC_0010241_01.jpg ISIC_0010241_Segmentation_01.png
# resample count: 180
# training: ISIC_0001118.jpg ISIC_0001118_Segmentation.png
# resample count: 180
# training: ISIC_0010014.jpg ISIC_0010014_Segmentation.png
# training: ISIC_0010014_01.jpg ISIC_0010014_Segmentation_01.png
# resample count: 181
# training: ISIC_0000317.jpg ISIC_0000317_Segmentation.png
# training: ISIC_0000317_01.jpg ISIC_0000317_Segmentation_01.png
# resample count: 182
# training: ISIC_0011145.jpg ISIC_0011145_Segmentation.png
# training: ISIC_0011145_01.jpg ISIC_0011145_Segmentation_01.png
# resample count: 183
# training: ISIC_0000303.jpg ISIC_0000303_Segmentation.png
# resample count: 183
# training: ISIC_0009986.jpg ISIC_0009986_Segmentation.png
# training: ISIC_0009986_01.jpg ISIC_0009986_Segmentation_01.png
# resample count: 184
# training: ISIC_0010492.jpg ISIC_0010492_Segmentation.png
# resample count: 184
# training: ISIC_0009919.jpg ISIC_0009919_Segmentation.png
# training: ISIC_0009919_01.jpg ISIC_0009919_Segmentation_01.png
# resample count: 185
# training: ISIC_0000379.jpg ISIC_0000379_Segmentation.png
# training: ISIC_0000379_01.jpg ISIC_0000379_Segmentation_01.png
# resample count: 186
# training: ISIC_0000087.jpg ISIC_0000087_Segmentation.png
# resample count: 186
# training: ISIC_0002353.jpg ISIC_0002353_Segmentation.png
# training: ISIC_0002353_01.jpg ISIC_0002353_Segmentation_01.png
# resample count: 187
# training: ISIC_0001262.jpg ISIC_0001262_Segmentation.png
# training: ISIC_0001262_01.jpg ISIC_0001262_Segmentation_01.png
# resample count: 188
# training: ISIC_0009910.jpg ISIC_0009910_Segmentation.png
# resample count: 188
# training: ISIC_0011323.jpg ISIC_0011323_Segmentation.png
# resample count: 188
# training: ISIC_0001212.jpg ISIC_0001212_Segmentation.png
# training: ISIC_0001212_01.jpg ISIC_0001212_Segmentation_01.png
# resample count: 189
# training: ISIC_0011346.jpg ISIC_0011346_Segmentation.png
# training: ISIC_0011346_01.jpg ISIC_0011346_Segmentation_01.png
# resample count: 190
# training: ISIC_0000224.jpg ISIC_0000224_Segmentation.png
# resample count: 190
# training: ISIC_0009947.jpg ISIC_0009947_Segmentation.png
# training: ISIC_0009947_01.jpg ISIC_0009947_Segmentation_01.png
# resample count: 191
# training: ISIC_0010218.jpg ISIC_0010218_Segmentation.png
# training: ISIC_0010218_01.jpg ISIC_0010218_Segmentation_01.png
# resample count: 192
# training: ISIC_0000555.jpg ISIC_0000555_Segmentation.png
# training: ISIC_0000555_01.jpg ISIC_0000555_Segmentation_01.png
# resample count: 193
# training: ISIC_0011114.jpg ISIC_0011114_Segmentation.png
# training: ISIC_0011114_01.jpg ISIC_0011114_Segmentation_01.png
# resample count: 194
# training: ISIC_0010450.jpg ISIC_0010450_Segmentation.png
# training: ISIC_0010450_01.jpg ISIC_0010450_Segmentation_01.png
# resample count: 195
# training: ISIC_0010367.jpg ISIC_0010367_Segmentation.png
# training: ISIC_0010367_01.jpg ISIC_0010367_Segmentation_01.png
# resample count: 196
# training: ISIC_0010362.jpg ISIC_0010362_Segmentation.png
# training: ISIC_0010362_01.jpg ISIC_0010362_Segmentation_01.png
# resample count: 197
# training: ISIC_0011127.jpg ISIC_0011127_Segmentation.png
# training: ISIC_0011127_01.jpg ISIC_0011127_Segmentation_01.png
# resample count: 198
# training: ISIC_0000047.jpg ISIC_0000047_Segmentation.png
# training: ISIC_0000047_01.jpg ISIC_0000047_Segmentation_01.png
# resample count: 199
# training: ISIC_0007475.jpg ISIC_0007475_Segmentation.png
# training: ISIC_0007475_01.jpg ISIC_0007475_Segmentation_01.png
# resample count: 200
# training: ISIC_0000511.jpg ISIC_0000511_Segmentation.png
# resample count: 200
# training: ISIC_0005555.jpg ISIC_0005555_Segmentation.png
# training: ISIC_0005555_01.jpg ISIC_0005555_Segmentation_01.png
# resample count: 201
# training: ISIC_0011203.jpg ISIC_0011203_Segmentation.png
# resample count: 201
# training: ISIC_0000131.jpg ISIC_0000131_Segmentation.png
# training: ISIC_0000131_01.jpg ISIC_0000131_Segmentation_01.png
# resample count: 202
# training: ISIC_0000017.jpg ISIC_0000017_Segmentation.png
# training: ISIC_0000017_01.jpg ISIC_0000017_Segmentation_01.png
# resample count: 203
# training: ISIC_0009981.jpg ISIC_0009981_Segmentation.png
# training: ISIC_0009981_01.jpg ISIC_0009981_Segmentation_01.png
# resample count: 204
# training: ISIC_0000096.jpg ISIC_0000096_Segmentation.png
# training: ISIC_0000096_01.jpg ISIC_0000096_Segmentation_01.png
# resample count: 205
# training: ISIC_0002976.jpg ISIC_0002976_Segmentation.png
# training: ISIC_0002976_01.jpg ISIC_0002976_Segmentation_01.png
# resample count: 206
# training: ISIC_0000034.jpg ISIC_0000034_Segmentation.png
# training: ISIC_0000034_01.jpg ISIC_0000034_Segmentation_01.png
# resample count: 207
# training: ISIC_0000243.jpg ISIC_0000243_Segmentation.png
# resample count: 207
# training: ISIC_0000242.jpg ISIC_0000242_Segmentation.png
# resample count: 207
# training: ISIC_0001102.jpg ISIC_0001102_Segmentation.png
# resample count: 207
# training: ISIC_0009915.jpg ISIC_0009915_Segmentation.png
# training: ISIC_0009915_01.jpg ISIC_0009915_Segmentation_01.png
# resample count: 208
# training: ISIC_0011079.jpg ISIC_0011079_Segmentation.png
# resample count: 208
# training: ISIC_0009929.jpg ISIC_0009929_Segmentation.png
# training: ISIC_0009929_01.jpg ISIC_0009929_Segmentation_01.png
# resample count: 209
# training: ISIC_0010577.jpg ISIC_0010577_Segmentation.png
# training: ISIC_0010577_01.jpg ISIC_0010577_Segmentation_01.png
# resample count: 210
# training: ISIC_0001254.jpg ISIC_0001254_Segmentation.png
# training: ISIC_0001254_01.jpg ISIC_0001254_Segmentation_01.png
# resample count: 211
# training: ISIC_0010264.jpg ISIC_0010264_Segmentation.png
# resample count: 211
# training: ISIC_0002476.jpg ISIC_0002476_Segmentation.png
# training: ISIC_0002476_01.jpg ISIC_0002476_Segmentation_01.png
# resample count: 212
# training: ISIC_0000016.jpg ISIC_0000016_Segmentation.png
# training: ISIC_0000016_01.jpg ISIC_0000016_Segmentation_01.png
# resample count: 213
# training: ISIC_0010581.jpg ISIC_0010581_Segmentation.png
# training: ISIC_0010581_01.jpg ISIC_0010581_Segmentation_01.png
# resample count: 214
# training: ISIC_0000100.jpg ISIC_0000100_Segmentation.png
# resample count: 214
# training: ISIC_0000176.jpg ISIC_0000176_Segmentation.png
# training: ISIC_0000176_01.jpg ISIC_0000176_Segmentation_01.png
# resample count: 215
# training: ISIC_0000130.jpg ISIC_0000130_Segmentation.png
# training: ISIC_0000130_01.jpg ISIC_0000130_Segmentation_01.png
# resample count: 216
# training: ISIC_0000151.jpg ISIC_0000151_Segmentation.png
# training: ISIC_0000151_01.jpg ISIC_0000151_Segmentation_01.png
# resample count: 217
# training: ISIC_0010042.jpg ISIC_0010042_Segmentation.png
# training: ISIC_0010042_01.jpg ISIC_0010042_Segmentation_01.png
# resample count: 218
# training: ISIC_0001106.jpg ISIC_0001106_Segmentation.png
# training: ISIC_0001106_01.jpg ISIC_0001106_Segmentation_01.png
# resample count: 219
# training: ISIC_0009921.jpg ISIC_0009921_Segmentation.png
# resample count: 219
# training: ISIC_0010043.jpg ISIC_0010043_Segmentation.png
# training: ISIC_0010043_01.jpg ISIC_0010043_Segmentation_01.png
# resample count: 220
# training: ISIC_0009964.jpg ISIC_0009964_Segmentation.png
# training: ISIC_0009964_01.jpg ISIC_0009964_Segmentation_01.png
# resample count: 221
# training: ISIC_0010204.jpg ISIC_0010204_Segmentation.png
# resample count: 221
# training: ISIC_0000280.jpg ISIC_0000280_Segmentation.png
# resample count: 221
# training: ISIC_0000221.jpg ISIC_0000221_Segmentation.png
# training: ISIC_0000221_01.jpg ISIC_0000221_Segmentation_01.png
# resample count: 222
# training: ISIC_0000395.jpg ISIC_0000395_Segmentation.png
# training: ISIC_0000395_01.jpg ISIC_0000395_Segmentation_01.png
# resample count: 223
# training: ISIC_0002975.jpg ISIC_0002975_Segmentation.png
# training: ISIC_0002975_01.jpg ISIC_0002975_Segmentation_01.png
# resample count: 224
# training: ISIC_0000387.jpg ISIC_0000387_Segmentation.png
# training: ISIC_0000387_01.jpg ISIC_0000387_Segmentation_01.png
# resample count: 225
# training: ISIC_0000049.jpg ISIC_0000049_Segmentation.png
# resample count: 225
# training: ISIC_0004715.jpg ISIC_0004715_Segmentation.png
# training: ISIC_0004715_01.jpg ISIC_0004715_Segmentation_01.png
# resample count: 226
# training: ISIC_0009975.jpg ISIC_0009975_Segmentation.png
# training: ISIC_0009975_01.jpg ISIC_0009975_Segmentation_01.png
# resample count: 227
# training: ISIC_0009899.jpg ISIC_0009899_Segmentation.png
# training: ISIC_0009899_01.jpg ISIC_0009899_Segmentation_01.png
# resample count: 228
# training: ISIC_0009875.jpg ISIC_0009875_Segmentation.png
# training: ISIC_0009875_01.jpg ISIC_0009875_Segmentation_01.png
# resample count: 229
# training: ISIC_0000187.jpg ISIC_0000187_Segmentation.png
# resample count: 229
# training: ISIC_0000207.jpg ISIC_0000207_Segmentation.png
# resample count: 229
# training: ISIC_0010457.jpg ISIC_0010457_Segmentation.png
# resample count: 229
# training: ISIC_0000193.jpg ISIC_0000193_Segmentation.png
# training: ISIC_0000193_01.jpg ISIC_0000193_Segmentation_01.png
# resample count: 230
# training: ISIC_0010256.jpg ISIC_0010256_Segmentation.png
# training: ISIC_0010256_01.jpg ISIC_0010256_Segmentation_01.png
# resample count: 231
# training: ISIC_0000480.jpg ISIC_0000480_Segmentation.png
# training: ISIC_0000480_01.jpg ISIC_0000480_Segmentation_01.png
# resample count: 232
# training: ISIC_0000336.jpg ISIC_0000336_Segmentation.png
# training: ISIC_0000336_01.jpg ISIC_0000336_Segmentation_01.png
# resample count: 233
# training: ISIC_0011140.jpg ISIC_0011140_Segmentation.png
# training: ISIC_0011140_01.jpg ISIC_0011140_Segmentation_01.png
# resample count: 234
# training: ISIC_0000135.jpg ISIC_0000135_Segmentation.png
# training: ISIC_0000135_01.jpg ISIC_0000135_Segmentation_01.png
# resample count: 235
# training: ISIC_0010438.jpg ISIC_0010438_Segmentation.png
# training: ISIC_0010438_01.jpg ISIC_0010438_Segmentation_01.png
# resample count: 236
# training: ISIC_0010594.jpg ISIC_0010594_Segmentation.png
# training: ISIC_0010594_01.jpg ISIC_0010594_Segmentation_01.png
# resample count: 237
# training: ISIC_0010585.jpg ISIC_0010585_Segmentation.png
# training: ISIC_0010585_01.jpg ISIC_0010585_Segmentation_01.png
# resample count: 238
# training: ISIC_0011136.jpg ISIC_0011136_Segmentation.png
# training: ISIC_0011136_01.jpg ISIC_0011136_Segmentation_01.png
# resample count: 239
# training: ISIC_0010247.jpg ISIC_0010247_Segmentation.png
# resample count: 239
# training: ISIC_0009976.jpg ISIC_0009976_Segmentation.png
# training: ISIC_0009976_01.jpg ISIC_0009976_Segmentation_01.png
# resample count: 240
# training: ISIC_0002287.jpg ISIC_0002287_Segmentation.png
# training: ISIC_0002287_01.jpg ISIC_0002287_Segmentation_01.png
# resample count: 241
# training: ISIC_0011306.jpg ISIC_0011306_Segmentation.png
# training: ISIC_0011306_01.jpg ISIC_0011306_Segmentation_01.png
# resample count: 242
# training: ISIC_0000059.jpg ISIC_0000059_Segmentation.png
# training: ISIC_0000059_01.jpg ISIC_0000059_Segmentation_01.png
# resample count: 243
# training: ISIC_0011126.jpg ISIC_0011126_Segmentation.png
# resample count: 243
# training: ISIC_0010490.jpg ISIC_0010490_Segmentation.png
# training: ISIC_0010490_01.jpg ISIC_0010490_Segmentation_01.png
# resample count: 244
# training: ISIC_0010032.jpg ISIC_0010032_Segmentation.png
# training: ISIC_0010032_01.jpg ISIC_0010032_Segmentation_01.png
# resample count: 245
# training: ISIC_0000453.jpg ISIC_0000453_Segmentation.png
# training: ISIC_0000453_01.jpg ISIC_0000453_Segmentation_01.png
# resample count: 246
# training: ISIC_0009873.jpg ISIC_0009873_Segmentation.png
# training: ISIC_0009873_01.jpg ISIC_0009873_Segmentation_01.png
# resample count: 247
# ...
# resample count: 492
# training: ISIC_0008256.jpg ISIC_0008256_Segmentation.png
# training: ISIC_0008256_01.jpg ISIC_0008256_Segmentation_01.png
# resample count: 493
# training: ISIC_0011301.jpg ISIC_0011301_Segmentation.png
# training: ISIC_0011301_01.jpg ISIC_0011301_Segmentation_01.png
# resample count: 494
# training: ISIC_0009870.jpg ISIC_0009870_Segmentation.png
# training: ISIC_0009870_01.jpg ISIC_0009870_Segmentation_01.png
# resample count: 495
# training: ISIC_0009888.jpg ISIC_0009888_Segmentation.png
# training: ISIC_0009888_01.jpg ISIC_0009888_Segmentation_01.png
# resample count: 496
# training: ISIC_0000419.jpg ISIC_0000419_Segmentation.png
# resample count: 496
# training: ISIC_0000182.jpg ISIC_0000182_Segmentation.png
# training: ISIC_0000182_01.jpg ISIC_0000182_Segmentation_01.png
# resample count: 497
# training: ISIC_0009950.jpg ISIC_0009950_Segmentation.png
# training: ISIC_0009950_01.jpg ISIC_0009950_Segmentation_01.png
# resample count: 498
# training: ISIC_0000105.jpg ISIC_0000105_Segmentation.png
# training: ISIC_0000105_01.jpg ISIC_0000105_Segmentation_01.png
# resample count: 499
# training: ISIC_0011082.jpg ISIC_0011082_Segmentation.png
# training: ISIC_0011082_01.jpg ISIC_0011082_Segmentation_01.png
# resample count: 500
# training: ISIC_0010487.jpg ISIC_0010487_Segmentation.png
# training: ISIC_0010487_01.jpg ISIC_0010487_Segmentation_01.png
# resample count: 501
# training: ISIC_0009165.jpg ISIC_0009165_Segmentation.png
# training: ISIC_0009165_01.jpg ISIC_0009165_Segmentation_01.png
# resample count: 502
# training: ISIC_0000097.jpg ISIC_0000097_Segmentation.png
# training: ISIC_0000097_01.jpg ISIC_0000097_Segmentation_01.png
# resample count: 503
# training: ISIC_0000191.jpg ISIC_0000191_Segmentation.png
# training: ISIC_0000191_01.jpg ISIC_0000191_Segmentation_01.png
# resample count: 504
# training: ISIC_0011393.jpg ISIC_0011393_Segmentation.png
# training: ISIC_0011393_01.jpg ISIC_0011393_Segmentation_01.png
# resample count: 505
# training: ISIC_0001213.jpg ISIC_0001213_Segmentation.png
# training: ISIC_0001213_01.jpg ISIC_0001213_Segmentation_01.png
# resample count: 506
# training: ISIC_0011141.jpg ISIC_0011141_Segmentation.png
# training: ISIC_0011141_01.jpg ISIC_0011141_Segmentation_01.png
# resample count: 507
# training: ISIC_0003005.jpg ISIC_0003005_Segmentation.png
# training: ISIC_0003005_01.jpg ISIC_0003005_Segmentation_01.png
# resample count: 508
# training: ISIC_0010443.jpg ISIC_0010443_Segmentation.png
# training: ISIC_0010443_01.jpg ISIC_0010443_Segmentation_01.png
# resample count: 509
# training: ISIC_0000496.jpg ISIC_0000496_Segmentation.png
# resample count: 509
# training: ISIC_0011382.jpg ISIC_0011382_Segmentation.png
# training: ISIC_0011382_01.jpg ISIC_0011382_Segmentation_01.png
# resample count: 510
# training: ISIC_0010104.jpg ISIC_0010104_Segmentation.png
# training: ISIC_0010104_01.jpg ISIC_0010104_Segmentation_01.png
# resample count: 511
# training: ISIC_0010382.jpg ISIC_0010382_Segmentation.png
# resample count: 511
# training: ISIC_0000498.jpg ISIC_0000498_Segmentation.png
# training: ISIC_0000498_01.jpg ISIC_0000498_Segmentation_01.png
# resample count: 512
# training: ISIC_0010025.jpg ISIC_0010025_Segmentation.png
# training: ISIC_0010025_01.jpg ISIC_0010025_Segmentation_01.png
# resample count: 513
# training: ISIC_0010054.jpg ISIC_0010054_Segmentation.png
# training: ISIC_0010054_01.jpg ISIC_0010054_Segmentation_01.png
# resample count: 514
# training: ISIC_0007788.jpg ISIC_0007788_Segmentation.png
# training: ISIC_0007788_01.jpg ISIC_0007788_Segmentation_01.png
# resample count: 515
# training: ISIC_0010174.jpg ISIC_0010174_Segmentation.png
# training: ISIC_0010174_01.jpg ISIC_0010174_Segmentation_01.png
# resample count: 516
# training: ISIC_0008785.jpg ISIC_0008785_Segmentation.png
# training: ISIC_0008785_01.jpg ISIC_0008785_Segmentation_01.png
# resample count: 517
# training: ISIC_0010334.jpg ISIC_0010334_Segmentation.png
# resample count: 517
# training: ISIC_0008879.jpg ISIC_0008879_Segmentation.png
# training: ISIC_0008879_01.jpg ISIC_0008879_Segmentation_01.png
# resample count: 518
# training: ISIC_0000208.jpg ISIC_0000208_Segmentation.png
# resample count: 518
# training: ISIC_0008396.jpg ISIC_0008396_Segmentation.png
# training: ISIC_0008396_01.jpg ISIC_0008396_Segmentation_01.png
# resample count: 519
# training: ISIC_0000153.jpg ISIC_0000153_Segmentation.png
# training: ISIC_0000153_01.jpg ISIC_0000153_Segmentation_01.png
# resample count: 520
# training: ISIC_0001216.jpg ISIC_0001216_Segmentation.png
# training: ISIC_0001216_01.jpg ISIC_0001216_Segmentation_01.png
# resample count: 521
# training: ISIC_0000002.jpg ISIC_0000002_Segmentation.png
# training: ISIC_0000002_01.jpg ISIC_0000002_Segmentation_01.png
# resample count: 522
# training: ISIC_0011158.jpg ISIC_0011158_Segmentation.png
# resample count: 522
# training: ISIC_0000142.jpg ISIC_0000142_Segmentation.png
# training: ISIC_0000142_01.jpg ISIC_0000142_Segmentation_01.png
# resample count: 523
# training: ISIC_0010479.jpg ISIC_0010479_Segmentation.png
# training: ISIC_0010479_01.jpg ISIC_0010479_Segmentation_01.png
# resample count: 524
# training: ISIC_0000121.jpg ISIC_0000121_Segmentation.png
# training: ISIC_0000121_01.jpg ISIC_0000121_Segmentation_01.png
# resample count: 525
# training: ISIC_0000483.jpg ISIC_0000483_Segmentation.png
# training: ISIC_0000483_01.jpg ISIC_0000483_Segmentation_01.png
# resample count: 526
# training: ISIC_0007557.jpg ISIC_0007557_Segmentation.png
# training: ISIC_0007557_01.jpg ISIC_0007557_Segmentation_01.png
# resample count: 527
# training: ISIC_0011397.jpg ISIC_0011397_Segmentation.png
# resample count: 527
# training: ISIC_0000021.jpg ISIC_0000021_Segmentation.png
# resample count: 527
# training: ISIC_0000410.jpg ISIC_0000410_Segmentation.png
# training: ISIC_0000410_01.jpg ISIC_0000410_Segmentation_01.png
# resample count: 528
# training: ISIC_0000051.jpg ISIC_0000051_Segmentation.png
# training: ISIC_0000051_01.jpg ISIC_0000051_Segmentation_01.png
# resample count: 529
# training: ISIC_0000250.jpg ISIC_0000250_Segmentation.png
# training: ISIC_0000250_01.jpg ISIC_0000250_Segmentation_01.png
# resample count: 530
# training: ISIC_0000506.jpg ISIC_0000506_Segmentation.png
# training: ISIC_0000506_01.jpg ISIC_0000506_Segmentation_01.png
# resample count: 531
# training: ISIC_0010317.jpg ISIC_0010317_Segmentation.png
# training: ISIC_0010317_01.jpg ISIC_0010317_Segmentation_01.png
# resample count: 532
# training: ISIC_0007087.jpg ISIC_0007087_Segmentation.png
# training: ISIC_0007087_01.jpg ISIC_0007087_Segmentation_01.png
# resample count: 533
# training: ISIC_0005187.jpg ISIC_0005187_Segmentation.png
# training: ISIC_0005187_01.jpg ISIC_0005187_Segmentation_01.png
# resample count: 534
# training: ISIC_0002885.jpg ISIC_0002885_Segmentation.png
# training: ISIC_0002885_01.jpg ISIC_0002885_Segmentation_01.png
# resample count: 535
# training: ISIC_0000048.jpg ISIC_0000048_Segmentation.png
# training: ISIC_0000048_01.jpg ISIC_0000048_Segmentation_01.png
# resample count: 536
# training: ISIC_0000415.jpg ISIC_0000415_Segmentation.png
# resample count: 536
# training: ISIC_0009951.jpg ISIC_0009951_Segmentation.png
# training: ISIC_0009951_01.jpg ISIC_0009951_Segmentation_01.png
# resample count: 537
# training: ISIC_0010344.jpg ISIC_0010344_Segmentation.png
# training: ISIC_0010344_01.jpg ISIC_0010344_Segmentation_01.png
# resample count: 538
# training: ISIC_0009800.jpg ISIC_0009800_Segmentation.png
# training: ISIC_0009800_01.jpg ISIC_0009800_Segmentation_01.png
# resample count: 539
# training: ISIC_0011169.jpg ISIC_0011169_Segmentation.png
# training: ISIC_0011169_01.jpg ISIC_0011169_Segmentation_01.png
# resample count: 540
# training: ISIC_0011109.jpg ISIC_0011109_Segmentation.png
# resample count: 540
# training: ISIC_0001105.jpg ISIC_0001105_Segmentation.png
# training: ISIC_0001105_01.jpg ISIC_0001105_Segmentation_01.png
# resample count: 541
# training: ISIC_0000170.jpg ISIC_0000170_Segmentation.png
# training: ISIC_0000170_01.jpg ISIC_0000170_Segmentation_01.png
# resample count: 542
# training: ISIC_0010194.jpg ISIC_0010194_Segmentation.png
# training: ISIC_0010194_01.jpg ISIC_0010194_Segmentation_01.png
# resample count: 543
# training: ISIC_0001286.jpg ISIC_0001286_Segmentation.png
# training: ISIC_0001286_01.jpg ISIC_0001286_Segmentation_01.png
# resample count: 544
# training: ISIC_0011095.jpg ISIC_0011095_Segmentation.png
# training: ISIC_0011095_01.jpg ISIC_0011095_Segmentation_01.png
# resample count: 545
# training: ISIC_0010602.jpg ISIC_0010602_Segmentation.png
# resample count: 545
# training: ISIC_0010235.jpg ISIC_0010235_Segmentation.png
# resample count: 545
# training: ISIC_0000274.jpg ISIC_0000274_Segmentation.png
# training: ISIC_0000274_01.jpg ISIC_0000274_Segmentation_01.png
# resample count: 546
# training: ISIC_0001292.jpg ISIC_0001292_Segmentation.png
# training: ISIC_0001292_01.jpg ISIC_0001292_Segmentation_01.png
# resample count: 547
# training: ISIC_0000292.jpg ISIC_0000292_Segmentation.png
# resample count: 547
# training: ISIC_0011361.jpg ISIC_0011361_Segmentation.png
# resample count: 547
# training: ISIC_0002879.jpg ISIC_0002879_Segmentation.png
# training: ISIC_0002879_01.jpg ISIC_0002879_Segmentation_01.png
# resample count: 548
# training: ISIC_0000341.jpg ISIC_0000341_Segmentation.png
# training: ISIC_0000341_01.jpg ISIC_0000341_Segmentation_01.png
# resample count: 549
# training: ISIC_0010080.jpg ISIC_0010080_Segmentation.png
# training: ISIC_0010080_01.jpg ISIC_0010080_Segmentation_01.png
# resample count: 550
# training: ISIC_0010473.jpg ISIC_0010473_Segmentation.png
# resample count: 550
# training: ISIC_0010105.jpg ISIC_0010105_Segmentation.png
# training: ISIC_0010105_01.jpg ISIC_0010105_Segmentation_01.png
# resample count: 551
# training: ISIC_0009505.jpg ISIC_0009505_Segmentation.png
# training: ISIC_0009505_01.jpg ISIC_0009505_Segmentation_01.png
# resample count: 552
# training: ISIC_0010071.jpg ISIC_0010071_Segmentation.png
# resample count: 552
# training: ISIC_0010074.jpg ISIC_0010074_Segmentation.png
# training: ISIC_0010074_01.jpg ISIC_0010074_Segmentation_01.png
# resample count: 553
# training: ISIC_0010365.jpg ISIC_0010365_Segmentation.png
# training: ISIC_0010365_01.jpg ISIC_0010365_Segmentation_01.png
# resample count: 554
# training: ISIC_0000080.jpg ISIC_0000080_Segmentation.png
# training: ISIC_0000080_01.jpg ISIC_0000080_Segmentation_01.png
# resample count: 555
# training: ISIC_0011348.jpg ISIC_0011348_Segmentation.png
# resample count: 555
# training: ISIC_0000503.jpg ISIC_0000503_Segmentation.png
# training: ISIC_0000503_01.jpg ISIC_0000503_Segmentation_01.png
# resample count: 556
# training: ISIC_0000467.jpg ISIC_0000467_Segmentation.png
# resample count: 556
# training: ISIC_0004110.jpg ISIC_0004110_Segmentation.png
# training: ISIC_0004110_01.jpg ISIC_0004110_Segmentation_01.png
# resample count: 557
# training: ISIC_0010464.jpg ISIC_0010464_Segmentation.png
# training: ISIC_0010464_01.jpg ISIC_0010464_Segmentation_01.png
# resample count: 558
# training: ISIC_0010029.jpg ISIC_0010029_Segmentation.png
# resample count: 558
# training: ISIC_0010372.jpg ISIC_0010372_Segmentation.png
# training: ISIC_0010372_01.jpg ISIC_0010372_Segmentation_01.png
# resample count: 559
# training: ISIC_0000255.jpg ISIC_0000255_Segmentation.png
# training: ISIC_0000255_01.jpg ISIC_0000255_Segmentation_01.png
# resample count: 560
# training: ISIC_0000367.jpg ISIC_0000367_Segmentation.png
# training: ISIC_0000367_01.jpg ISIC_0000367_Segmentation_01.png
# resample count: 561
# training: ISIC_0010465.jpg ISIC_0010465_Segmentation.png
# training: ISIC_0010465_01.jpg ISIC_0010465_Segmentation_01.png
# resample count: 562
# training: ISIC_0011200.jpg ISIC_0011200_Segmentation.png
# training: ISIC_0011200_01.jpg ISIC_0011200_Segmentation_01.png
# resample count: 563
# training: ISIC_0009932.jpg ISIC_0009932_Segmentation.png
# resample count: 563
# training: ISIC_0000236.jpg ISIC_0000236_Segmentation.png
# resample count: 563
# training: ISIC_0010189.jpg ISIC_0010189_Segmentation.png
# resample count: 563
# training: ISIC_0002439.jpg ISIC_0002439_Segmentation.png
# training: ISIC_0002439_01.jpg ISIC_0002439_Segmentation_01.png
# resample count: 564
# training: ISIC_0002647.jpg ISIC_0002647_Segmentation.png
# training: ISIC_0002647_01.jpg ISIC_0002647_Segmentation_01.png
# resample count: 565
# training: ISIC_0009905.jpg ISIC_0009905_Segmentation.png
# training: ISIC_0009905_01.jpg ISIC_0009905_Segmentation_01.png
# resample count: 566
# training: ISIC_0000045.jpg ISIC_0000045_Segmentation.png
# training: ISIC_0000045_01.jpg ISIC_0000045_Segmentation_01.png
# resample count: 567
# training: ISIC_0009991.jpg ISIC_0009991_Segmentation.png
# resample count: 567
# training: ISIC_0000488.jpg ISIC_0000488_Segmentation.png
# training: ISIC_0000488_01.jpg ISIC_0000488_Segmentation_01.png
# resample count: 568
# training: ISIC_0011390.jpg ISIC_0011390_Segmentation.png
# resample count: 568
# training: ISIC_0000210.jpg ISIC_0000210_Segmentation.png
# training: ISIC_0000210_01.jpg ISIC_0000210_Segmentation_01.png
# resample count: 569
# training: ISIC_0011387.jpg ISIC_0011387_Segmentation.png
# resample count: 569
# training: ISIC_0010064.jpg ISIC_0010064_Segmentation.png
# training: ISIC_0010064_01.jpg ISIC_0010064_Segmentation_01.png
# resample count: 570
# training: ISIC_0009941.jpg ISIC_0009941_Segmentation.png
# training: ISIC_0009941_01.jpg ISIC_0009941_Segmentation_01.png
# resample count: 571
# training: ISIC_0002206.jpg ISIC_0002206_Segmentation.png
# training: ISIC_0002206_01.jpg ISIC_0002206_Segmentation_01.png
# resample count: 572
# training: ISIC_0010349.jpg ISIC_0010349_Segmentation.png
# resample count: 572
# training: ISIC_0000307.jpg ISIC_0000307_Segmentation.png
# resample count: 572
# training: ISIC_0011317.jpg ISIC_0011317_Segmentation.png
# training: ISIC_0011317_01.jpg ISIC_0011317_Segmentation_01.png
# resample count: 573
# training: ISIC_0000315.jpg ISIC_0000315_Segmentation.png
# training: ISIC_0000315_01.jpg ISIC_0000315_Segmentation_01.png
# resample count: 574
# training: ISIC_0000530.jpg ISIC_0000530_Segmentation.png
# training: ISIC_0000530_01.jpg ISIC_0000530_Segmentation_01.png
# resample count: 575
# training: ISIC_0010079.jpg ISIC_0010079_Segmentation.png
# resample count: 575
# training: ISIC_0000492.jpg ISIC_0000492_Segmentation.png
# training: ISIC_0000492_01.jpg ISIC_0000492_Segmentation_01.png
# resample count: 576
# training: ISIC_0000063.jpg ISIC_0000063_Segmentation.png
# resample count: 576
# training: ISIC_0010246.jpg ISIC_0010246_Segmentation.png
# training: ISIC_0010246_01.jpg ISIC_0010246_Segmentation_01.png
# resample count: 577
# training: ISIC_0010053.jpg ISIC_0010053_Segmentation.png
# training: ISIC_0010053_01.jpg ISIC_0010053_Segmentation_01.png
# resample count: 578
# training: ISIC_0000114.jpg ISIC_0000114_Segmentation.png
# training: ISIC_0000114_01.jpg ISIC_0000114_Segmentation_01.png
# resample count: 579
# training: ISIC_0010006.jpg ISIC_0010006_Segmentation.png
# training: ISIC_0010006_01.jpg ISIC_0010006_Segmentation_01.png
# resample count: 580
# training: ISIC_0000199.jpg ISIC_0000199_Segmentation.png
# training: ISIC_0000199_01.jpg ISIC_0000199_Segmentation_01.png
# resample count: 581
# training: ISIC_0000163.jpg ISIC_0000163_Segmentation.png
# training: ISIC_0000163_01.jpg ISIC_0000163_Segmentation_01.png
# resample count: 582
# training: ISIC_0009978.jpg ISIC_0009978_Segmentation.png
# training: ISIC_0009978_01.jpg ISIC_0009978_Segmentation_01.png
# resample count: 583
# training: ISIC_0010852.jpg ISIC_0010852_Segmentation.png
# training: ISIC_0010852_01.jpg ISIC_0010852_Segmentation_01.png
# resample count: 584
# training: ISIC_0000386.jpg ISIC_0000386_Segmentation.png
# training: ISIC_0000386_01.jpg ISIC_0000386_Segmentation_01.png
# resample count: 585
# training: ISIC_0011223.jpg ISIC_0011223_Segmentation.png
# training: ISIC_0011223_01.jpg ISIC_0011223_Segmentation_01.png
# resample count: 586
# training: ISIC_0010330.jpg ISIC_0010330_Segmentation.png
# resample count: 586
# training: ISIC_0011400.jpg ISIC_0011400_Segmentation.png
# training: ISIC_0011400_01.jpg ISIC_0011400_Segmentation_01.png
# resample count: 587
# training: ISIC_0000504.jpg ISIC_0000504_Segmentation.png
# training: ISIC_0000504_01.jpg ISIC_0000504_Segmentation_01.png
# resample count: 588
# training: ISIC_0010075.jpg ISIC_0010075_Segmentation.png
# resample count: 588
# training: ISIC_0009967.jpg ISIC_0009967_Segmentation.png
# training: ISIC_0009967_01.jpg ISIC_0009967_Segmentation_01.png
# resample count: 589

# %%
test_data_dirname = 'ISBI2016_ISIC_Part1_Test_Data'
test_data_dir_path = os.path.join(base_dir_path, test_data_dirname)

test_gt_dirname = 'ISBI2016_ISIC_Part1_Test_GroundTruth'
test_gt_dir_path = os.path.join(base_dir_path, test_gt_dirname)

test_image_filenames=[]
for root, _, files in os.walk(test_data_dir_path):
    for name in files:
        test_image_filenames.append(name) 

test_image_filenames.sort()

test_mask_filenames=[]
for root, _, files in os.walk(test_gt_dir_path):
    for name in files:
        test_mask_filenames.append(name) 

test_mask_filenames.sort()


# no cropping or resizing for testing samples
test_list_filename = 'isbi2016_isic_part1_test_v8.list'
test_list_filepath = os.path.join(base_dir_path, test_list_filename)
test_list_file = open(test_list_filepath, 'w')

merged = list(zip(test_image_filenames, test_mask_filenames))

for image_file, mask_file in merged:
    print('test: ' + image_file + " " + mask_file)
    print(image_file + " " + mask_file, file=test_list_file)

test_list_file.close()

# %%
from PIL import Image
import numpy as np
import os

base_dir_path = os.path.normpath('C:/Users/kirta/Documents/research/data')

training_out_dirname = 'ISBI2016_ISIC_Part1_Training_Data_v8_processed'
training_out_dir_path = os.path.join(base_dir_path, training_out_dirname)


for root, _, files in os.walk(training_out_dir_path):
    for name in files:
        img = Image.open(os.path.join(root, name))
        if img.width < 480 or img.height < 480:   
            print(os.path.join(root, name) + " width " + str(img.width) + " height " + str(img.height))
